# %%
import pandas

# %%
dataset = pandas.read_excel("myexcelproject.xlsx")

# %%
import pandas as pd

# %%
dataset = pd.read_excel("myexcelproject.xlsx")

# %%
dataset
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
import numpy as np

# Replace the 'Height' column with random values
np.random.seed(42)
dataset['Height'] = np.random.randint(150, 181, size=len(dataset))

# Verify the changes
display(dataset.head())
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     156     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     169     235
# 2   John Holland  Boston Celtics      30       SG   27     178     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     164     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     160     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
team_distribution = dataset['Team'].value_counts()
team_percentage = (team_distribution / len(dataset)) * 100

# Combine results into a DataFrame
team_summary = pd.DataFrame({
    'Count': team_distribution,
    'Percentage': team_percentage
})
display(team_summary)
# Out:
#                         Count  Percentage
# Team
# New Orleans Pelicans       19    4.148472
# Memphis Grizzlies          18    3.930131
# Utah Jazz                  16    3.493450
# Milwaukee Bucks            16    3.493450
# New York Knicks            16    3.493450
# Boston Celtics             15    3.275109
# Los Angeles Clippers       15    3.275109
# Los Angeles Lakers         15    3.275109
# Phoenix Suns               15    3.275109
# Sacramento Kings           15    3.275109
# Brooklyn Nets              15    3.275109
# Philadelphia 76ers         15    3.275109
# Toronto Raptors            15    3.275109
# Golden State Warriors      15    3.275109
# Indiana Pacers             15    3.275109
# Detroit Pistons            15    3.275109
# Cleveland Cavaliers        15    3.275109
# Chicago Bulls              15    3.275109
# Houston Rockets            15    3.275109
# San Antonio Spurs          15    3.275109
# Atlanta Hawks              15    3.275109
# ...

# %%
import matplotlib.pyplot as plt

# Pie chart
team_distribution.plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Employee Distribution by Team')
plt.ylabel('')
plt.show()

# %%
position_distribution = dataset['Position'].value_counts()
display(position_distribution)
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
position_distribution.plot(kind='bar', color='skyblue')
plt.title('Employee Distribution by Position')
plt.xlabel('Position')
plt.ylabel('Count')
plt.show()

# %%
age_bins = [18, 25, 35, 45, 55, 65]
dataset['Age Group'] = pd.cut(dataset['Age'], bins=age_bins)
age_group_distribution = dataset['Age Group'].value_counts()
display(age_group_distribution)
# Out:
# Age Group
# (25, 35]    235
# (18, 25]    200
# (35, 45]     23
# (45, 55]      0
# (55, 65]      0
# Name: count, dtype: int64

# %%
age_group_distribution.plot(kind='bar', color='coral')
plt.title('Employee Age Group Distribution')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()

# %%
team_salary = dataset.groupby('Team')['Salary'].sum()
position_salary = dataset.groupby('Position')['Salary'].sum()

# Find the highest salary expenditures
highest_team = team_salary.idxmax()
highest_position = position_salary.idxmax()
print(f"Highest Salary by Team: {highest_team} (${team_salary[highest_team]:,.2f})")
print(f"Highest Salary by Position: {highest_position} (${position_salary[highest_position]:,.2f})")
# Out:
# Highest Salary by Team: Cleveland Cavaliers ($106,988,689.00)
# Highest Salary by Position: C ($466,377,332.00)

# %%
team_salary.sort_values().plot(kind='barh', color='lightgreen')
plt.title('Total Salary by Team')
plt.xlabel('Total Salary')
plt.show()

# %%
correlation = dataset[['Age', 'Salary']].corr()
print("Correlation between Age and Salary:")
print(correlation)

# Scatter plot
plt.scatter(dataset['Age'], dataset['Salary'], color='purple', alpha=0.6)
plt.title('Age vs Salary Correlation')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()
# Out:
# Correlation between Age and Salary:
#              Age    Salary
# Age     1.000000  0.214009
# Salary  0.214009  1.000000
